# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *

filter = 3

# %%
def plot(data, error, ecolor='r', fmt='--', label=None):
    x = data[0, :]
    y = data[1, :]
    plt.errorbar(x, y, yerr=error, ecolor=ecolor, capsize=3, fmt=fmt, label=label)

# %%
data_baseline = get_mixrw_rate('../results/MRW-24-30-3', step=10)
avg_baseline = np.zeros((2, 11))
std_baseline = np.zeros((11))
cnt = 0
for i, d in data_baseline.items():
    avg_baseline[0, cnt] = i
    avg_baseline[1, cnt], std_baseline[cnt] = avg_rate(d, filter=filter)
    cnt += 1
# Out:
# files:
# ../results/MRW-24-30-3/MIXREADWRITE-0.0.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.1.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.2.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.3.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.4.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.5.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.6.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.7.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.8.dat
# ../results/MRW-24-30-3/MIXREADWRITE-0.9.dat
# ../results/MRW-24-30-3/MIXREADWRITE-1.0.dat

# %%
data_contention = get_mixrw_rate('../results/Contention-24-30-3', step=10)
avg_contention = np.zeros((2, 11))
std_contention = np.zeros((11))
cnt = 0
for i, d in data_contention.items():
    avg_contention[0, cnt] = i
    avg_contention[1, cnt], std_contention[cnt] = avg_rate(d, filter=filter)
    cnt += 1
# Out:
# files:
# ../results/Contention-24-30-3/MIXREADWRITE-0.0.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.1.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.2.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.3.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.4.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.5.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.6.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.7.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.8.dat
# ../results/Contention-24-30-3/MIXREADWRITE-0.9.dat
# ../results/Contention-24-30-3/MIXREADWRITE-1.0.dat

# %%
# data refer to WSR.ipynb
x_wsr = [0.33, 0.2, 0.15]
avg_wsr = [4905.8154477317385, 4133.761764596584, 3737.3845511428794]
std_wsr = [482.164221911337, 158.3049062750301, 188.67836038990103]
avg_wsr_contention = 5068.694748442665
std_wsr_contention = 619.2467422597597

# data refer to lock.ipynb
x_ar = 0.60
avg_ar = 1277.0237060819636
std_ar = 100.22451527412716

plt.figure()

plot(avg_baseline, std_baseline, ecolor='r', label='baseline')
plot(avg_contention, std_contention, ecolor='g', label='contention')
plot(np.array([x_wsr, avg_wsr]), std_wsr, ecolor='r', fmt='--', label='WSR')
plot(np.array([[0.33], [avg_wsr_contention]]), [std_wsr_contention], ecolor='g', fmt='.', label='WSR+Contention')
plot(np.array([[x_ar], [avg_ar]]), [std_ar], ecolor='r', fmt='.', label='Acquire-Release')

plt.xlabel('Read Percentage')
plt.ylabel('Operations Per Second')
plt.title('Throughput Performance')
plt.legend()
plt.show()

# %%
plt.figure()

plot(avg_baseline, std_baseline, ecolor='r', label='baseline')

plt.xlabel('Read Percentage')
plt.ylabel('Operations Per Second')
plt.title('Throughput Performance')
plt.legend()

plt.savefig('throughput_plots/baseline.png')
plt.show()

# %%
plt.figure()

plot(avg_baseline, std_baseline, ecolor='r', label='baseline')
plot(avg_contention, std_contention, ecolor='g', label='contention')

plt.xlabel('Read Percentage')
plt.ylabel('Operations Per Second')
plt.title('Throughput Performance')
plt.legend()

plt.savefig('throughput_plots/contention.png')
plt.show()

# %%
plt.figure()

plot(avg_baseline, std_baseline, ecolor='r', label='baseline')
plot(np.array([[0.5], [avg_wsr[0]]]), std_wsr[0], ecolor='r', fmt='--', label='WSR')
plot(np.array([[0.5], [avg_wsr_contention]]), [std_wsr_contention], ecolor='b', fmt='.', label='WSR+Contention')

plt.ylim([2000, 10000])
plt.xlabel('Read Percentage')
plt.ylabel('Operations Per Second')
plt.title('Throughput Performance')
plt.legend()

plt.savefig('throughput_plots/WSR.png')
plt.show()

# %%
plt.figure()

plot(avg_baseline, std_baseline, ecolor='r', label='baseline')
plot(np.array([[x_ar], [avg_ar]]), [std_ar], ecolor='r', fmt='.', label='lock')

plt.xlim([0.4, 0.8])
plt.ylim([0, 12500])
plt.xlabel('Read Percentage')
plt.ylabel('Operations Per Second')
plt.title('Throughput Performance')
plt.legend()

plt.savefig('throughput_plots/lock.png')
plt.show()
